# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
x = [0,25,50,75,100,110]
y = [0,4,8,12,16,20]

fig=plt.figure(figsize=(20,10))

plt.subplot(221)
plt.plot(x, y)

plt.subplot(222)
plt.scatter(x, y)

# %% [markdown]
# <h3 style = "text-align: center">test pandas and matplotlib</h3>

# %%
df = pd.DataFrame({
    'Name':['rap', 'yok', 'din', 'joe'],
    'Age':[18, 20, 30, 40]
})
print("graph data Name and Age with friends")
# df.plot(x='Name', y='Age', kind="bar")
plt.bar(df["Name"], df["Age"])
plt.show()


print("graph data scatter")
plt.scatter(df["Name"], df["Age"])
plt.show()
# Out:
# graph data Name and Age with friends
# graph data scatter
